# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\pranj\Downloads\Employee Dataset.csv")

# %%
df.head()
# Out:
#    id groups  age  healthy_eating  active_lifestyle  salary
# 0   0      A   36               5                 5    2297
# 1   1      A   26               3                 5    1134
# 2   2      A   61               8                 1    4969
# 3   3      O   24               3                 6     902
# 4   4      O   39               6                 2    3574

# %%
df.shape
# Out:
# (50, 6)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %% [markdown]
# df.columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                50 non-null     int64
#  1   groups            50 non-null     object
#  2   age               50 non-null     int64
#  3   healthy_eating    50 non-null     int64
#  4   active_lifestyle  50 non-null     int64
#  5   salary            50 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 2.5+ KB

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=df,x='age',y='salary',color='blue',edgecolor='linen',alpha=0.5)
plt.xlabel('Employee Age')
plt.ylabel('Employee Salary')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=df,x='healthy_eating',y='active_lifestyle',color='red',edgecolor='linen',alpha=0.5)
plt.xlabel('healthy eating')
plt.ylabel('active_lifestyle')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=df,x='healthy_eating',y='salary',color='k',edgecolor='linen',alpha=0.5)
plt.xlabel('healthy eating')
plt.ylabel('salary')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df, x='groups',edgecolor='linen', alpha=0.7)
plt.xlabel('Groups')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(11,6))
sns.countplot(data=df, x='salary',edgecolor='linen', alpha=0.7)
plt.xlabel('salary')
plt.ylabel('Count')
plt.show()

# %%
sub1=df[df['healthy_eating']>8]
sub1
# Out:
#     id groups  age  healthy_eating  active_lifestyle  salary
# 26  26      A   62               9                 6     700

# %%
sub2=df[df['salary']<1000]
sub2
# Out:
#     id groups  age  healthy_eating  active_lifestyle  salary
# 3    3      O   24               3                 6     902
# 15  15      B   26               3                 8     662
# 18  18      A   27               2                 6     779
# 26  26      A   62               9                 6     700
# 32  32      A   22               3                 8     662
# 35  35      O   27               2                 4     785
# 38  38     AB   26               3                 7     670
# 39  39      B   29               2                 6     779
# 43  43      O   23               4                10     556

# %%
sub=df[(df['healthy_eating']>8) & (df['salary']<1000)]

# %%
sub
# Out:
#     id groups  age  healthy_eating  active_lifestyle  salary
# 26  26      A   62               9                 6     700

# %% [markdown]
# ### Final Conclusions

# %% [markdown]
# # From the given data,we can use simple visiualzation to get a sense of how data are distributed.We can conduct preliminary analysis simply by subsetting data sets using well well thought out thresholds and conditions.
